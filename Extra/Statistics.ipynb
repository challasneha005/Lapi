# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import statistics

# %%
#mean ,mode ,median
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
np.mean(df['total_bill'])
# Out:
# np.float64(19.78594262295082)

# %%
np.median(df['total_bill'])
# Out:
# np.float64(17.795)

# %%
statistics.mode(df['total_bill'])
# Out:
# 13.42

# %%
sns.boxplot(df['total_bill'])
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.histplot(df['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(df['total_bill'],kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
 df1 = sns.load_dataset('iris')
print(df1.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.histplot(df1['sepal_length'],kde=True)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(df1['sepal_width'],kde=True)
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
sns.countplot(df1['species'])
# Out:
# <Axes: xlabel='count', ylabel='species'>

# %%
np.percentile(df1['sepal_length'],[25,75])
# Out:
# array([5.1, 6.4])

# %% [markdown]
# # Outliers

# %%
dataset = [11,10,12,14,12,15,13,15,102,12,14,17,19,107,10,13,12,14,12,108,12,11,12,13,15,13,15,10,15,12,10,14,13,15,10]
plt.hist(dataset)
outliers = []
def detect_outliers(data):
    threshold = 3
    mean = np.mean(data)
    std = np.std(data)

    for i in dataset:
        z_score = (i - mean)/std
        if(np.abs(z_score) > threshold):
            outliers.append(i)
    return outliers

# %%
detect_outliers(dataset)
# Out:
# [102, 107, 108]

# %%
#IQR

# %%
#1.sort data
#2.calc Q1 and Q3
#3.IQR(Q3-Q1)
#4.find lower fence(q1 - 1.5(iqr))
#5.find upper fence(q3 + 1.5(iqr))

d = np.sort(dataset)
print(d)
# Out:
# [ 10  10  10  10  10  11  11  12  12  12  12  12  12  12  12  13  13  13
#   13  13  14  14  14  14  15  15  15  15  15  15  17  19 102 107 108]

# %%
q1,q3 = np.percentile(dataset,[25,75])
print(q1,q3)
# Out:
# 12.0 15.0

# %%
iqr = q3 - q1
print(iqr)
# Out:
# 3.0

# %%
#find lower and higher fence
lower = q1 - (1.5*iqr)
higher = q3 + (1.5*iqr)
print(lower,higher)
# Out:
# 7.5 19.5

# %%
sns.boxplot(dataset)
# Out:
# <Axes: >

# %%
''' Suppose the IQ in a certain population is normally distributed with a mean of mu=100 and std 0f 100
A researcher wants to know if a new drug affects IQ levels ,so he recruits 20patients  to try to record their IQ levels.
The following code shows how to perform a one sample z-test in python '''
# Out:
# ' Suppose the IQ in a certain population is normally distributed with a mean of mu=100 and std 0f 100\nA researcher wants to know if a new drug affects IQ levels ,so he recruits 20patients  to try to record their IQ levels.\nThe following code shows how to perform a one sample z-test in python '

# %%
from statsmodels.stats.weightstats import ztest as ztest
#IQ of 20 patients
data = [88,92,94,94,96,97,97,97,97,99,99,105,109,109,109,110,112,112,113,114,115]
print(ztest(data,value=110))
# Out:
# (np.float64(-3.9367142829163972), np.float64(8.260485980931933e-05))

# %%
#t test
ages =[10,20,35,50,28,40,55,18,16,55,30,25,43,18,30,28,14,24,16,17,32,35,26,27,65,18,43,23,21,20,19,70]
import numpy as np
mean = np.mean(ages)
print(mean)
# Out:
# 30.34375

# %%
sample = 10
age_s = np.random.choice(ages,sample)
print(age_s)
# Out:
# [32 18 65 65 16 27 18 27 65 27]

# %%
from scipy.stats import ttest_1samp

# %%
ttest_1samp(age_s,30)
# Out:
# TtestResult(statistic=np.float64(0.9197570345536727), pvalue=np.float64(0.3816903376689623), df=np.int64(9))

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import math
np.random.seed(6)
s_ages=stats.poisson.rvs(loc=18,mu=35,size=1500)
a=s_ages=stats.poisson.rvs(loc=18,mu=35,size=60)
print(s_ages)
print(a)
# Out:
# [58 51 57 45 44 52 55 56 50 49 57 51 59 47 49 57 55 60 46 60 50 67 58 54
#  51 52 45 50 57 47 50 53 55 45 58 49 60 59 44 49 50 59 47 51 39 69 56 56
#  51 53 47 52 39 57 58 43 48 53 44 46]
# [58 51 57 45 44 52 55 56 50 49 57 51 59 47 49 57 55 60 46 60 50 67 58 54
#  51 52 45 50 57 47 50 53 55 45 58 49 60 59 44 49 50 59 47 51 39 69 56 56
#  51 53 47 52 39 57 58 43 48 53 44 46]

# %%
a.mean()
# Out:
# np.float64(52.15)

# %%
_,p_value = ttest_1samp(a,popmean=s_ages.mean())

# %%
s_ages.mean()
# Out:
# np.float64(52.15)

# %%
print(p_value)
if p_value<=0.05:
    print("reject h0")
else:
    print("accept h0")
# Out:
# 1.0
# accept h0

# %%
import seaborn as sns
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df.corr()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# ...

# %%
sns.pairplot(df)
